# %% [markdown]
# <a href="https://colab.research.google.com/github/jlegatheaux/RC2020-assignments/blob/master/assignment-2/assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook Setup
# You must execute the cell below ***once*** before proceeding...

# %%
# %%bash
# rm -rf *
# git clone https://github.com/jlegatheaux/RC2020-assignments.git RC 2> /dev/null || git -C RC pull
# mv -f RC/assignment-2/* .
#
# # Fetch the CNSS repository and compile it
# git clone https://github.com/jlegatheaux/cnss.git 2> /dev/null || git -C cnss pull
# javac -d cnss-classes cnss/src/*/*/*.java

# %% [markdown]
# #Laboratory project - Reliable Data Transmission over an Unreliable Network with the FT20 Protocol
#
# # Goal
#
# This assignment concerns the problem of delivering information reliably across a network where a degree of packet loss is expected.
#
# The goal is to understand how the performance of sliding window protocols is impacted by parameter choices, such as fixed timeouts, adaptative timeouts, windows sizes, as well as the flow control technique employed etc.
#
# # Context
#
# This assignment will use a simple file transfer protocol, between a client and a server, implemented in the CNSS simulator.
#
# # FT20 Protocol
#
# The FT20 protocol, developed for this assignment, allows for the reliable transfer of a file from a client to a server, over an unreliable network. This protocol comprises a total of 5 types of packets, namely `UPLOAD`, `ERROR`, `DATA`, `ACK` and `FIN`.
#
# ## FT20 Packets
#
# Each packet type is identified by an 1-byte numeric *opcode*. The format and purpose of each packet is as follows:
#
# * ***UPLOAD***
#
#   `|1|timestamp|filename|`
#
#   Initiates the transfer of the file with the given `filename. This packet has 0 as its implicit *sequence number*.
#
# * ***ERROR***
#
#   `|2|errormessage|`
#
#   Reports a fatal error.
#
# * ***DATA***
#
#   `|3|timestamp|seqN|data|`
#
#   Represents a block of file data. The block is identified by a *sequence number* (`seqN´), starting at 1, for the first block of a file.
#
#   `data` - the file block payload encoded as raw bytes.
#
# * ***ACK***
#
#   `|4|timestamp|cSeqN|sSeqN|`
#
#   Confirms correctly received packets.
#
#   `cSeqN` - Represents a **cumulative sequence number** that acknowledges **all** packets up to and including the given value.
#
#   `sSeqN` - Acknowledges the **given** packet, identified by this `sSeqN` value. A value of ***-1** means this field is *invalid/not present*.
#
# * ***FIN***
#
#   `|5|timestamp|seqN|`
#
#   Signals the file transfer is complete. The sequence number (`seqN`) should be 1 past the last block of the file.
#
# When present, the `timestamp` field is expected to contain the time the packet was sent. For ACK packets, the `timestamp` is obtained/copied from the packet that generated that ACK packet. Used in this way, the `timestamp` can be used to sample  the RTT between the client and server nodes.
#
# The Cumulative Sequence Numbers issued by the server support the **Go back N** (GBN) version of the sliding window protocol. Selective Sequence Numbers can be used to support the **Selective Repeat** version of the same protocol.
#
# ## FT20 File Transfer
#
# The figure below illustrates the packet exchange between the client and server, using the `Stop&Wait` protocol.
# ![](https://docs.google.com/drawings/d/e/2PACX-1vSrnzM0E_KnSi9R5NW1GReXt9IjW36o7kT3oS-JgOPn2Hhigy3iyA40xRlo2IYvQpmegOvx6RpFfg1y/pub?w=509&h=539)
#
# To achieve a reliable file transfer, `UPLOAD`, `DATA` and `FIN` packets are retransmitted until acknowledged by the server.

# %% [markdown]
# ## CNSS Simulation
#
# ### FT20 Packets
# To implement the FT20 Protocol in CNSS, we require a way to encode FT20 packets as CNSS data packets.
#
# [FT20Packet.java](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/src/ft20/FT20Packet.java) is a Java class to encode FT20Packets into arrays of bytes, which can be used as the payloads of CNSS [DataPackets](https://github.com/jlegatheaux/cnss/blob/master/src/cnss/simulator/DataPacket.java). Conversely, the same class allows an array of bytes to be decoded into an FT20Packet. The only relevant public methods are `encodeToBytes()` and `decodeFromBytes()`.
#
# Companion classes: [FT20_UploadPacket](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/src/ft20/FT20_UploadPacket.java), [FT20_DataPacket](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/src/ft20/FT20_DataPacket.java), [FT20_AckPacket](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/src/ft20/FT20_AckPacket.java), [FT20_FinPacket](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/src/ft20/FT20_FinPacket.java), [FT20_ErrorPacket](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/src/ft20/FT20_ErrorPacket.java) model each specific FT20 packet type. These classes expose FT20 Packet fields as public **immutable** data. In these classes, the public constructors is the only way to assemble new FT20 packets.
#
# The box below reproduces the [FT20_UploadPacket](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/src/ft20/FT20_UploadPacket.java) class, which models the UPLOAD packet.

# %%
# %%writefile src/ft20/FT20_UploadPacket.java
#
# package ft20;
#
# public class FT20_UploadPacket extends FT20Packet {
#         public int timestamp;
#         public final String filename;
#
#         FT20_UploadPacket(byte[] payload) {
#                 super(payload);
#                 this.timestamp = super.getInt();
#                 this.filename = super.getString();
#         }
#
#         public FT20_UploadPacket(String filename, int timestamp) {
#                 super(UPLOAD);
#                 this.timestamp = timestamp;
#                 this.filename = filename;
#                 super.putInt(timestamp).putString(filename);
#         }
#
#         public String toString() {
#                 return String.format("UPLOAD<%s, %d>", filename, timestamp);
#         }
# }
# Out:
# Overwriting src/ft20/FT20_UploadPacket.java

# %% [markdown]
# ### FT20 Nodes
#
# The *client* and *server* nodes of the FT20 protocol can be implemented in CNSS directly on top of the [ApplicationAlgorithm](https://github.com/jlegatheaux/cnss/blob/master/src/cnss/simulator/ApplicationAlgorithm.java) or [AbstractApplicationAlgorithm](https://github.com/jlegatheaux/cnss/blob/master/src/cnss/lib/AbstractApplicationAlgorithm.java) classes.
#
# Alternatively, the client and server nodes can extend the [FT20AbstractApplication](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/src/ft20/FT20AbstractApplication.java) class. This way, the handling of FT20 packets is greatly simplified. Namely, this class uses the [FT20_PacketHandler](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/src/ft20/FT20_PacketHandler.java) interface to provide specific *upcalls* for each of the FT20 packet types.
#
# ### Stop&Wait Example
#
#   * ***SERVER***

# %%
# %%writefile src/FT20Server.java
#
# import java.io.*;
# import java.util.*;
#
# import cnss.simulator.*;
# import ft20.*;
#
# public class FT20Server extends FT20AbstractApplication implements FT20_PacketHandler {
#
# 	private int windowSize; // by default in blocks
#
# 	private SortedMap<Integer, byte[]> window = new TreeMap<>();
#
# 	private int nextSeqN;
# 	private String filename;
# 	private FileOutputStream fos;
#
# 	public FT20Server() {
# 		super(true, "   FT20-Server");
# 	}
#
# 	@Override
# 	public int initialise(int now, int nodeId, Node self, String[] args) {
# 		super.initialise(now, nodeId, self, args, this);
# 		if( args.length != 1 ) {
# 			System.err.println( this.getClass().getSimpleName() + " missing windowSize argument [in config file]");
# 			System.exit(-1);
# 		}
# 		this.windowSize = Integer.parseInt(args[0]);
# 		this.fos = null;
# 		this.nextSeqN = 0;
# 		return 0;
# 	}
#
# 	@Override
# 	public void on_receive_upload(int now, int client, FT20_UploadPacket upload) {
# 		if (nextSeqN <= 1) {
# 			super.sendPacket(now, client, new FT20_AckPacket(0, 0, upload.timestamp));
# 			nextSeqN = 1;
# 			window.clear();
# 			filename = upload.filename;
# 		} else
# 			super.sendPacket(now, client,
# 					new FT20_ErrorPacket("Unexpected packet type...[Already initiated a transfer...]"));
# 	}
#
# 	@Override
# 	public void on_receive_data(int now, int client, FT20_DataPacket data) {
#
# 		// outside the window.
# 		if (data.seqN < nextSeqN || data.seqN > nextSeqN + windowSize)
# 			super.sendPacket(now, client, new FT20_AckPacket(nextSeqN - 1, -1, data.timestamp));
# 		else {
#
# 			window.putIfAbsent(data.seqN, data.block);
#
# 			//try to slide window and flush to disk.
# 			byte[] block;
# 			while ((block = window.remove(nextSeqN)) != null) {
# 				writeBlockToFile(block);
# 				nextSeqN += 1;
# 			}
# 			super.sendPacket(now, client, new FT20_AckPacket(nextSeqN - 1, data.seqN, data.timestamp));
# 		}
# 	}
#
# 	@Override
# 	public void on_receive_fin(int now, int client, FT20_FinPacket fin) {
# 		if (window.isEmpty() && nextSeqN == fin.seqN)
# 			super.printReport( now );
#
# 		super.sendPacket(now, client, new FT20_AckPacket(fin.seqN, fin.seqN, fin.timestamp));
# 	}
#
# 	private void writeBlockToFile(byte[] data) {
# 		try {
# 			if (fos == null)
# 				fos = new FileOutputStream("copy-of-" + filename);
# 			fos.write(data);
# 		} catch (Exception x) {
# 			System.err.println("FATAL ERROR: " + x.getMessage());
# 			System.exit(-1);
# 		}
# 	}
# }
# Out:
# Overwriting src/FT20Server.java

# %% [markdown]
#   * ***CLIENT***

# %%
# %%writefile src/FT20ClientSW.java
#
# import java.io.*;
#
# import ft20.*;
# import cnss.simulator.*;
#
# public class FT20ClientSW extends FT20AbstractApplication implements FT20_PacketHandler {
#
# 	static int SERVER = 1;
#
# 	enum State {
# 		BEGINNING, UPLOADING, FINISHING
# 	};
#
# 	static int DEFAULT_TIMEOUT = 1000;
#
# 	private File file;
# 	private RandomAccessFile raf;
# 	private int BlockSize;
# 	private int nextPacketSeqN, lastPacketSeqN;
#
# 	private State state;
#
# 	public FT20ClientSW() {
# 		super(true, "FT20-ClientSW");
# 	}
#
# 	public int initialise(int now, int node_id, Node nodeObj, String[] args) {
# 		super.initialise(now, node_id, nodeObj, args, this);
#
# 		raf = null;
# 		file = new File(args[0]);
# 		BlockSize = Integer.parseInt(args[1]);
#
# 		state = State.BEGINNING;
# 		lastPacketSeqN = (int) Math.ceil(file.length() / (double)BlockSize);
#
# 		sendNextPacket(now);
# 		return 0;
# 	}
#
# 	private void sendNextPacket(int now) {
# 		switch (state) {
# 		case BEGINNING:
# 			super.sendPacket(now, SERVER, new FT20_UploadPacket(file.getName(), now));
# 			break;
# 		case UPLOADING:
# 			super.sendPacket(now, SERVER, readDataPacket(file, nextPacketSeqN, now));
# 			break;
# 		case FINISHING:
# 			super.sendPacket(now, SERVER, new FT20_FinPacket(nextPacketSeqN, now));
# 			break;
# 		}
# 		self.set_timeout(DEFAULT_TIMEOUT);
# 	}
#
# 	public void on_timeout(int now) {
# 		super.on_timeout(now);
# 		sendNextPacket(now);
# 	}
#
# 	@Override
# 	public void on_receive_ack(int now, int client, FT20_AckPacket ack) {
# 		switch (state) {
# 		case BEGINNING:
# 			state = State.UPLOADING;
# 		case UPLOADING:
# 			nextPacketSeqN = ack.cSeqN + 1;
# 			if (nextPacketSeqN > lastPacketSeqN)
# 				state = State.FINISHING;
# 			break;
# 		case FINISHING:
# 			super.log(now, "All Done. Transfer complete...");
# 			super.printReport( now );
# 			return;
# 		}
# 		sendNextPacket(now);
# 	}
#
# 	private FT20_DataPacket readDataPacket(File file, int seqN, int timestamp) {
# 		try {
# 			if (raf == null)
# 				raf = new RandomAccessFile(file, "r");
#
# 			raf.seek(BlockSize * (seqN - 1));
# 			byte[] data = new byte[BlockSize];
# 			int nbytes = raf.read(data);
# 			return new FT20_DataPacket(seqN, timestamp, data, nbytes);
# 		} catch (Exception x) {
# 			throw new Error("Fatal Error: " + x.getMessage());
# 		}
# 	}
# }
# Out:
# Overwriting src/FT20ClientSW.java

# %% [markdown]
#   * ***Configuration***

# %%
# %%writefile configs/config-2.1.txt
# # A network with a sender node and a receiver node interconnected
# # by a direct link. The link has 2 Mbps bandwidth and 20 ms latency
#
#
# # uncomment if you want to see control algorithms traces
# # parameter trace
#
#
# Node 0 1 cnss.lib.EndSystemControl FT20ClientSW earth.jpg 1000
# Node 1 1 cnss.lib.EndSystemControl FT20Server 5
#
# Link 0.0 1.0 2000000 20 0.25 0.0
# Out:
# Overwriting configs/config-2.1.txt

# %% [markdown]
#   * ***Execution***

# %%
# %%bash
# javac -cp .:cnss-classes -d ft20-classes src/*/*.java src/*.java
#
# java -cp .:cnss-classes:ft20-classes cnss.simulator.Simulator configs/config-2.1.txt > results.txt ; cat results.txt
# Out:
# Loading configuration : configs/config-2.1.txt
# Reading file
# Created Node 0: 1 interf.s, ctr code: cnss.lib.EndSystemControl app code: FT20ClientSW
# Created Node 1: 1 interf.s, ctr code: cnss.lib.EndSystemControl app code: FT20Server
# Added link to node 0 - Link (Node1:0 I1:0)<-->(Node2:1 I2:0) bwd: 2000000 bps lat: 20 ms error %: 0.25 jit %: 0.0 up
# Added link to node 1 - Link (Node1:0 I1:0)<-->(Node2:1 I2:0) bwd: 2000000 bps lat: 20 ms error %: 0.25 jit %: 0.0 up
#
# simulation starts - first processing step with clock = 0
#
# log: FT20-ClientSW time 0 node 0 SENDING: UPLOAD<earth.jpg, 0>
# log:    FT20-Server time 20 node 1 GOT: UPLOAD<earth.jpg, 0>
# log:    FT20-Server time 20 node 1 SENDING: ACK<0, 0, 0>
# log: FT20-ClientSW time 40 node 0 GOT: ACK<0, 0, 0>
# log: FT20-ClientSW time 40 node 0 SENDING: DATA<1, 40, len: 1000>
# log:    FT20-Server time 64 node 1 GOT: DATA<1, 40, len: 1000>
# log:    FT20-Server time 64 node 1 SENDING: ACK<1, 1, 40>
# log: FT20-ClientSW time 84 node 0 GOT: ACK<1, 1, 40>
# log: FT20-ClientSW time 84 node 0 SENDING: DATA<2, 84, len: 1000>
# log:    FT20-Server time 108 node 1 GOT: DATA<2, 84, len: 1000>
# log:    FT20-Server time 108 node 1 SENDING: ACK<2, 2, 84>
# log: FT20-ClientSW time 128 node 0 GOT: ACK<2, 2, 84>
# log: FT20-ClientSW time 128 node 0 SENDING: DATA<3, 128, len: 1000>
# log:    FT20-Server time 152 node 1 GOT: DATA<3, 128, len: 1000>
# log:    FT20-Server time 152 node 1 SENDING: ACK<3, 3, 128>
# log: FT20-ClientSW time 172 node 0 GOT: ACK<3, 3, 128>
# log: FT20-ClientSW time 172 node 0 SENDING: DATA<4, 172, len: 1000>
# log:    FT20-Server time 196 node 1 GOT: DATA<4, 172, len: 1000>
# log:    FT20-Server time 196 node 1 SENDING: ACK<4, 4, 172>
# log: FT20-ClientSW time 216 node 0 GOT: ACK<4, 4, 172>
# log: FT20-ClientSW time 216 node 0 SENDING: DATA<5, 216, len: 1000>
# log:    FT20-Server time 240 node 1 GOT: DATA<5, 216, len: 1000>
# log:    FT20-Server time 240 node 1 SENDING: ACK<5, 5, 216>
# log: FT20-ClientSW time 260 node 0 GOT: ACK<5, 5, 216>
# log: FT20-ClientSW time 260 node 0 SENDING: DATA<6, 260, len: 1000>
# log:    FT20-Server time 284 node 1 GOT: DATA<6, 260, len: 1000>
# log:    FT20-Server time 284 node 1 SENDING: ACK<6, 6, 260>
# log: FT20-ClientSW time 304 node 0 GOT: ACK<6, 6, 260>
# log: FT20-ClientSW time 304 node 0 SENDING: DATA<7, 304, len: 1000>
# log:    FT20-Server time 328 node 1 GOT: DATA<7, 304, len: 1000>
# log:    FT20-Server time 328 node 1 SENDING: ACK<7, 7, 304>
# log: FT20-ClientSW time 348 node 0 GOT: ACK<7, 7, 304>
# log: FT20-ClientSW time 348 node 0 SENDING: DATA<8, 348, len: 1000>
# log:    FT20-Server time 372 node 1 GOT: DATA<8, 348, len: 1000>
# log:    FT20-Server time 372 node 1 SENDING: ACK<8, 8, 348>
# log: FT20-ClientSW time 392 node 0 GOT: ACK<8, 8, 348>
# log: FT20-ClientSW time 392 node 0 SENDING: DATA<9, 392, len: 1000>
# log:    FT20-Server time 416 node 1 GOT: DATA<9, 392, len: 1000>
# log:    FT20-Server time 416 node 1 SENDING: ACK<9, 9, 392>
# log: FT20-ClientSW time 436 node 0 GOT: ACK<9, 9, 392>
# log: FT20-ClientSW time 436 node 0 SENDING: DATA<10, 436, len: 1000>
# log:    FT20-Server time 460 node 1 GOT: DATA<10, 436, len: 1000>
# log:    FT20-Server time 460 node 1 SENDING: ACK<10, 10, 436>
# log: FT20-ClientSW time 480 node 0 GOT: ACK<10, 10, 436>
# log: FT20-ClientSW time 480 node 0 SENDING: DATA<11, 480, len: 1000>
# log:    FT20-Server time 504 node 1 GOT: DATA<11, 480, len: 1000>
# log:    FT20-Server time 504 node 1 SENDING: ACK<11, 11, 480>
# log: FT20-ClientSW time 524 node 0 GOT: ACK<11, 11, 480>
# log: FT20-ClientSW time 524 node 0 SENDING: DATA<12, 524, len: 1000>
# log:    FT20-Server time 548 node 1 GOT: DATA<12, 524, len: 1000>
# log:    FT20-Server time 548 node 1 SENDING: ACK<12, 12, 524>
# log: FT20-ClientSW time 568 node 0 GOT: ACK<12, 12, 524>
# log: FT20-ClientSW time 568 node 0 SENDING: DATA<13, 568, len: 1000>
# log:    FT20-Server time 592 node 1 GOT: DATA<13, 568, len: 1000>
# log:    FT20-Server time 592 node 1 SENDING: ACK<13, 13, 568>
# log: FT20-ClientSW time 612 node 0 GOT: ACK<13, 13, 568>
# log: FT20-ClientSW time 612 node 0 SENDING: DATA<14, 612, len: 1000>
# log:    FT20-Server time 636 node 1 GOT: DATA<14, 612, len: 1000>
# log:    FT20-Server time 636 node 1 SENDING: ACK<14, 14, 612>
# log: FT20-ClientSW time 656 node 0 GOT: ACK<14, 14, 612>
# log: FT20-ClientSW time 656 node 0 SENDING: DATA<15, 656, len: 1000>
# log:    FT20-Server time 680 node 1 GOT: DATA<15, 656, len: 1000>
# log:    FT20-Server time 680 node 1 SENDING: ACK<15, 15, 656>
# log: FT20-ClientSW time 700 node 0 GOT: ACK<15, 15, 656>
# log: FT20-ClientSW time 700 node 0 SENDING: DATA<16, 700, len: 1000>
# log:    FT20-Server time 724 node 1 GOT: DATA<16, 700, len: 1000>
# log:    FT20-Server time 724 node 1 SENDING: ACK<16, 16, 700>
# log: FT20-ClientSW time 744 node 0 GOT: ACK<16, 16, 700>
# log: FT20-ClientSW time 744 node 0 SENDING: DATA<17, 744, len: 1000>
# log:    FT20-Server time 768 node 1 GOT: DATA<17, 744, len: 1000>
# log:    FT20-Server time 768 node 1 SENDING: ACK<17, 17, 744>
# log: FT20-ClientSW time 788 node 0 GOT: ACK<17, 17, 744>
# log: FT20-ClientSW time 788 node 0 SENDING: DATA<18, 788, len: 1000>
# log:    FT20-Server time 812 node 1 GOT: DATA<18, 788, len: 1000>
# log:    FT20-Server time 812 node 1 SENDING: ACK<18, 18, 788>
# log: FT20-ClientSW time 832 node 0 GOT: ACK<18, 18, 788>
# log: FT20-ClientSW time 832 node 0 SENDING: DATA<19, 832, len: 1000>
# log:    FT20-Server time 856 node 1 GOT: DATA<19, 832, len: 1000>
# log:    FT20-Server time 856 node 1 SENDING: ACK<19, 19, 832>
# log: FT20-ClientSW time 876 node 0 GOT: ACK<19, 19, 832>
# log: FT20-ClientSW time 876 node 0 SENDING: DATA<20, 876, len: 1000>
# log:    FT20-Server time 900 node 1 GOT: DATA<20, 876, len: 1000>
# log:    FT20-Server time 900 node 1 SENDING: ACK<20, 20, 876>
# log: FT20-ClientSW time 920 node 0 GOT: ACK<20, 20, 876>
# log: FT20-ClientSW time 920 node 0 SENDING: DATA<21, 920, len: 1000>
# log:    FT20-Server time 944 node 1 GOT: DATA<21, 920, len: 1000>
# log:    FT20-Server time 944 node 1 SENDING: ACK<21, 21, 920>
# log: FT20-ClientSW time 964 node 0 GOT: ACK<21, 21, 920>
# log: FT20-ClientSW time 964 node 0 SENDING: DATA<22, 964, len: 1000>
# log:    FT20-Server time 988 node 1 GOT: DATA<22, 964, len: 1000>
# log:    FT20-Server time 988 node 1 SENDING: ACK<22, 22, 964>
# log: FT20-ClientSW time 1008 node 0 GOT: ACK<22, 22, 964>
# log: FT20-ClientSW time 1008 node 0 SENDING: DATA<23, 1008, len: 1000>
# log:    FT20-Server time 1032 node 1 GOT: DATA<23, 1008, len: 1000>
# log:    FT20-Server time 1032 node 1 SENDING: ACK<23, 23, 1008>
# log: FT20-ClientSW time 1052 node 0 GOT: ACK<23, 23, 1008>
# log: FT20-ClientSW time 1052 node 0 SENDING: DATA<24, 1052, len: 1000>
# log:    FT20-Server time 1076 node 1 GOT: DATA<24, 1052, len: 1000>
# log:    FT20-Server time 1076 node 1 SENDING: ACK<24, 24, 1052>
# log: FT20-ClientSW time 1096 node 0 GOT: ACK<24, 24, 1052>
# log: FT20-ClientSW time 1096 node 0 SENDING: DATA<25, 1096, len: 1000>
# log:    FT20-Server time 1120 node 1 GOT: DATA<25, 1096, len: 1000>
# log:    FT20-Server time 1120 node 1 SENDING: ACK<25, 25, 1096>
# log: FT20-ClientSW time 1140 node 0 GOT: ACK<25, 25, 1096>
# log: FT20-ClientSW time 1140 node 0 SENDING: DATA<26, 1140, len: 1000>
# log:    FT20-Server time 1164 node 1 GOT: DATA<26, 1140, len: 1000>
# log:    FT20-Server time 1164 node 1 SENDING: ACK<26, 26, 1140>
# log: FT20-ClientSW time 1184 node 0 GOT: ACK<26, 26, 1140>
# log: FT20-ClientSW time 1184 node 0 SENDING: DATA<27, 1184, len: 1000>
# log:    FT20-Server time 1208 node 1 GOT: DATA<27, 1184, len: 1000>
# log:    FT20-Server time 1208 node 1 SENDING: ACK<27, 27, 1184>
# log: FT20-ClientSW time 1228 node 0 GOT: ACK<27, 27, 1184>
# log: FT20-ClientSW time 1228 node 0 SENDING: DATA<28, 1228, len: 1000>
# log:    FT20-Server time 1252 node 1 GOT: DATA<28, 1228, len: 1000>
# log:    FT20-Server time 1252 node 1 SENDING: ACK<28, 28, 1228>
# log: FT20-ClientSW time 1272 node 0 GOT: ACK<28, 28, 1228>
# log: FT20-ClientSW time 1272 node 0 SENDING: DATA<29, 1272, len: 1000>
# log:    FT20-Server time 1296 node 1 GOT: DATA<29, 1272, len: 1000>
# log:    FT20-Server time 1296 node 1 SENDING: ACK<29, 29, 1272>
# log: FT20-ClientSW time 1316 node 0 GOT: ACK<29, 29, 1272>
# log: FT20-ClientSW time 1316 node 0 SENDING: DATA<30, 1316, len: 1000>
# log:    FT20-Server time 1340 node 1 GOT: DATA<30, 1316, len: 1000>
# log:    FT20-Server time 1340 node 1 SENDING: ACK<30, 30, 1316>
# log: FT20-ClientSW time 1360 node 0 GOT: ACK<30, 30, 1316>
# log: FT20-ClientSW time 1360 node 0 SENDING: DATA<31, 1360, len: 1000>
# log:    FT20-Server time 1384 node 1 GOT: DATA<31, 1360, len: 1000>
# log:    FT20-Server time 1384 node 1 SENDING: ACK<31, 31, 1360>
# log: FT20-ClientSW time 1404 node 0 GOT: ACK<31, 31, 1360>
# log: FT20-ClientSW time 1404 node 0 SENDING: DATA<32, 1404, len: 1000>
# log:    FT20-Server time 1428 node 1 GOT: DATA<32, 1404, len: 1000>
# log:    FT20-Server time 1428 node 1 SENDING: ACK<32, 32, 1404>
# log: FT20-ClientSW time 1448 node 0 GOT: ACK<32, 32, 1404>
# log: FT20-ClientSW time 1448 node 0 SENDING: DATA<33, 1448, len: 1000>
# log:    FT20-Server time 1472 node 1 GOT: DATA<33, 1448, len: 1000>
# log:    FT20-Server time 1472 node 1 SENDING: ACK<33, 33, 1448>
# log: FT20-ClientSW time 1492 node 0 GOT: ACK<33, 33, 1448>
# log: FT20-ClientSW time 1492 node 0 SENDING: DATA<34, 1492, len: 1000>
# log:    FT20-Server time 1516 node 1 GOT: DATA<34, 1492, len: 1000>
# log:    FT20-Server time 1516 node 1 SENDING: ACK<34, 34, 1492>
# log: FT20-ClientSW time 1536 node 0 GOT: ACK<34, 34, 1492>
# log: FT20-ClientSW time 1536 node 0 SENDING: DATA<35, 1536, len: 1000>
# log:    FT20-Server time 1560 node 1 GOT: DATA<35, 1536, len: 1000>
# log:    FT20-Server time 1560 node 1 SENDING: ACK<35, 35, 1536>
# log: FT20-ClientSW time 1580 node 0 GOT: ACK<35, 35, 1536>
# log: FT20-ClientSW time 1580 node 0 SENDING: DATA<36, 1580, len: 1000>
# log:    FT20-Server time 1604 node 1 GOT: DATA<36, 1580, len: 1000>
# log:    FT20-Server time 1604 node 1 SENDING: ACK<36, 36, 1580>
# log: FT20-ClientSW time 1624 node 0 GOT: ACK<36, 36, 1580>
# log: FT20-ClientSW time 1624 node 0 SENDING: DATA<37, 1624, len: 1000>
# log:    FT20-Server time 1648 node 1 GOT: DATA<37, 1624, len: 1000>
# log:    FT20-Server time 1648 node 1 SENDING: ACK<37, 37, 1624>
# log: FT20-ClientSW time 1668 node 0 GOT: ACK<37, 37, 1624>
# log: FT20-ClientSW time 1668 node 0 SENDING: DATA<38, 1668, len: 1000>
# log:    FT20-Server time 1692 node 1 GOT: DATA<38, 1668, len: 1000>
# log:    FT20-Server time 1692 node 1 SENDING: ACK<38, 38, 1668>
# log: FT20-ClientSW time 1712 node 0 GOT: ACK<38, 38, 1668>
# log: FT20-ClientSW time 1712 node 0 SENDING: DATA<39, 1712, len: 1000>
# log:    FT20-Server time 1736 node 1 GOT: DATA<39, 1712, len: 1000>
# log:    FT20-Server time 1736 node 1 SENDING: ACK<39, 39, 1712>
# log: FT20-ClientSW time 1756 node 0 GOT: ACK<39, 39, 1712>
# log: FT20-ClientSW time 1756 node 0 SENDING: DATA<40, 1756, len: 1000>
# log:    FT20-Server time 1780 node 1 GOT: DATA<40, 1756, len: 1000>
# log:    FT20-Server time 1780 node 1 SENDING: ACK<40, 40, 1756>
# log: FT20-ClientSW time 1800 node 0 GOT: ACK<40, 40, 1756>
# log: FT20-ClientSW time 1800 node 0 SENDING: DATA<41, 1800, len: 1000>
# log:    FT20-Server time 1824 node 1 GOT: DATA<41, 1800, len: 1000>
# log:    FT20-Server time 1824 node 1 SENDING: ACK<41, 41, 1800>
# log: FT20-ClientSW time 1844 node 0 GOT: ACK<41, 41, 1800>
# log: FT20-ClientSW time 1844 node 0 SENDING: DATA<42, 1844, len: 1000>
# log:    FT20-Server time 1868 node 1 GOT: DATA<42, 1844, len: 1000>
# log:    FT20-Server time 1868 node 1 SENDING: ACK<42, 42, 1844>
# log: FT20-ClientSW time 1888 node 0 GOT: ACK<42, 42, 1844>
# log: FT20-ClientSW time 1888 node 0 SENDING: DATA<43, 1888, len: 1000>
# log:    FT20-Server time 1912 node 1 GOT: DATA<43, 1888, len: 1000>
# log:    FT20-Server time 1912 node 1 SENDING: ACK<43, 43, 1888>
# log: FT20-ClientSW time 1932 node 0 GOT: ACK<43, 43, 1888>
# log: FT20-ClientSW time 1932 node 0 SENDING: DATA<44, 1932, len: 1000>
# log:    FT20-Server time 1956 node 1 GOT: DATA<44, 1932, len: 1000>
# log:    FT20-Server time 1956 node 1 SENDING: ACK<44, 44, 1932>
# log: FT20-ClientSW time 1976 node 0 GOT: ACK<44, 44, 1932>
# log: FT20-ClientSW time 1976 node 0 SENDING: DATA<45, 1976, len: 1000>
# log:    FT20-Server time 2000 node 1 GOT: DATA<45, 1976, len: 1000>
# log:    FT20-Server time 2000 node 1 SENDING: ACK<45, 45, 1976>
# log: FT20-ClientSW time 2020 node 0 GOT: ACK<45, 45, 1976>
# log: FT20-ClientSW time 2020 node 0 SENDING: DATA<46, 2020, len: 1000>
# log:    FT20-Server time 2044 node 1 GOT: DATA<46, 2020, len: 1000>
# log:    FT20-Server time 2044 node 1 SENDING: ACK<46, 46, 2020>
# log: FT20-ClientSW time 2064 node 0 GOT: ACK<46, 46, 2020>
# log: FT20-ClientSW time 2064 node 0 SENDING: DATA<47, 2064, len: 1000>
# log:    FT20-Server time 2088 node 1 GOT: DATA<47, 2064, len: 1000>
# log:    FT20-Server time 2088 node 1 SENDING: ACK<47, 47, 2064>
# log: FT20-ClientSW time 2108 node 0 GOT: ACK<47, 47, 2064>
# log: FT20-ClientSW time 2108 node 0 SENDING: DATA<48, 2108, len: 1000>
# log:    FT20-Server time 2132 node 1 GOT: DATA<48, 2108, len: 1000>
# log:    FT20-Server time 2132 node 1 SENDING: ACK<48, 48, 2108>
# log: FT20-ClientSW time 2152 node 0 GOT: ACK<48, 48, 2108>
# log: FT20-ClientSW time 2152 node 0 SENDING: DATA<49, 2152, len: 1000>
# log:    FT20-Server time 2176 node 1 GOT: DATA<49, 2152, len: 1000>
# log:    FT20-Server time 2176 node 1 SENDING: ACK<49, 49, 2152>
# log: FT20-ClientSW time 2196 node 0 GOT: ACK<49, 49, 2152>
# log: FT20-ClientSW time 2196 node 0 SENDING: DATA<50, 2196, len: 1000>
# log:    FT20-Server time 2220 node 1 GOT: DATA<50, 2196, len: 1000>
# log:    FT20-Server time 2220 node 1 SENDING: ACK<50, 50, 2196>
# log: FT20-ClientSW time 2240 node 0 GOT: ACK<50, 50, 2196>
# log: FT20-ClientSW time 2240 node 0 SENDING: DATA<51, 2240, len: 1000>
# log:    FT20-Server time 2264 node 1 GOT: DATA<51, 2240, len: 1000>
# log:    FT20-Server time 2264 node 1 SENDING: ACK<51, 51, 2240>
# log: FT20-ClientSW time 2284 node 0 GOT: ACK<51, 51, 2240>
# log: FT20-ClientSW time 2284 node 0 SENDING: DATA<52, 2284, len: 1000>
# log:    FT20-Server time 2308 node 1 GOT: DATA<52, 2284, len: 1000>
# log:    FT20-Server time 2308 node 1 SENDING: ACK<52, 52, 2284>
# log: FT20-ClientSW time 2328 node 0 GOT: ACK<52, 52, 2284>
# log: FT20-ClientSW time 2328 node 0 SENDING: DATA<53, 2328, len: 1000>
# log:    FT20-Server time 2352 node 1 GOT: DATA<53, 2328, len: 1000>
# log:    FT20-Server time 2352 node 1 SENDING: ACK<53, 53, 2328>
# log: FT20-ClientSW time 2372 node 0 GOT: ACK<53, 53, 2328>
# log: FT20-ClientSW time 2372 node 0 SENDING: DATA<54, 2372, len: 1000>
# log:    FT20-Server time 2396 node 1 GOT: DATA<54, 2372, len: 1000>
# log:    FT20-Server time 2396 node 1 SENDING: ACK<54, 54, 2372>
# log: FT20-ClientSW time 2416 node 0 GOT: ACK<54, 54, 2372>
# log: FT20-ClientSW time 2416 node 0 SENDING: DATA<55, 2416, len: 1000>
# log:    FT20-Server time 2440 node 1 GOT: DATA<55, 2416, len: 1000>
# log:    FT20-Server time 2440 node 1 SENDING: ACK<55, 55, 2416>
# log: FT20-ClientSW time 2460 node 0 GOT: ACK<55, 55, 2416>
# log: FT20-ClientSW time 2460 node 0 SENDING: DATA<56, 2460, len: 1000>
# log:    FT20-Server time 2484 node 1 GOT: DATA<56, 2460, len: 1000>
# log:    FT20-Server time 2484 node 1 SENDING: ACK<56, 56, 2460>
# log: FT20-ClientSW time 2504 node 0 GOT: ACK<56, 56, 2460>
# log: FT20-ClientSW time 2504 node 0 SENDING: DATA<57, 2504, len: 1000>
# log:    FT20-Server time 2528 node 1 GOT: DATA<57, 2504, len: 1000>
# log:    FT20-Server time 2528 node 1 SENDING: ACK<57, 57, 2504>
# log: FT20-ClientSW time 2548 node 0 GOT: ACK<57, 57, 2504>
# log: FT20-ClientSW time 2548 node 0 SENDING: DATA<58, 2548, len: 1000>
# log:    FT20-Server time 2572 node 1 GOT: DATA<58, 2548, len: 1000>
# log:    FT20-Server time 2572 node 1 SENDING: ACK<58, 58, 2548>
# log: FT20-ClientSW time 2592 node 0 GOT: ACK<58, 58, 2548>
# log: FT20-ClientSW time 2592 node 0 SENDING: DATA<59, 2592, len: 1000>
# log:    FT20-Server time 2616 node 1 GOT: DATA<59, 2592, len: 1000>
# log:    FT20-Server time 2616 node 1 SENDING: ACK<59, 59, 2592>
# log: FT20-ClientSW time 2636 node 0 GOT: ACK<59, 59, 2592>
# log: FT20-ClientSW time 2636 node 0 SENDING: DATA<60, 2636, len: 1000>
# log:    FT20-Server time 2660 node 1 GOT: DATA<60, 2636, len: 1000>
# log:    FT20-Server time 2660 node 1 SENDING: ACK<60, 60, 2636>
# log: FT20-ClientSW time 2680 node 0 GOT: ACK<60, 60, 2636>
# log: FT20-ClientSW time 2680 node 0 SENDING: DATA<61, 2680, len: 1000>
# log:    FT20-Server time 2704 node 1 GOT: DATA<61, 2680, len: 1000>
# log:    FT20-Server time 2704 node 1 SENDING: ACK<61, 61, 2680>
# log: FT20-ClientSW time 2724 node 0 GOT: ACK<61, 61, 2680>
# log: FT20-ClientSW time 2724 node 0 SENDING: DATA<62, 2724, len: 1000>
# log:    FT20-Server time 2748 node 1 GOT: DATA<62, 2724, len: 1000>
# log:    FT20-Server time 2748 node 1 SENDING: ACK<62, 62, 2724>
# log: FT20-ClientSW time 2768 node 0 GOT: ACK<62, 62, 2724>
# log: FT20-ClientSW time 2768 node 0 SENDING: DATA<63, 2768, len: 1000>
# log:    FT20-Server time 2792 node 1 GOT: DATA<63, 2768, len: 1000>
# log:    FT20-Server time 2792 node 1 SENDING: ACK<63, 63, 2768>
# log: FT20-ClientSW time 2812 node 0 GOT: ACK<63, 63, 2768>
# log: FT20-ClientSW time 2812 node 0 SENDING: DATA<64, 2812, len: 1000>
# log:    FT20-Server time 2836 node 1 GOT: DATA<64, 2812, len: 1000>
# log:    FT20-Server time 2836 node 1 SENDING: ACK<64, 64, 2812>
# log: FT20-ClientSW time 2856 node 0 GOT: ACK<64, 64, 2812>
# log: FT20-ClientSW time 2856 node 0 SENDING: DATA<65, 2856, len: 1000>
# log:    FT20-Server time 2878 node 1 GOT: DATA<65, 2856, len: 645>
# log:    FT20-Server time 2878 node 1 SENDING: ACK<65, 65, 2856>
# log: FT20-ClientSW time 2898 node 0 GOT: ACK<65, 65, 2856>
# log: FT20-ClientSW time 2898 node 0 SENDING: FIN<66, 2898>
# log:    FT20-Server time 2918 node 1 GOT: FIN<66, 2898>
#
# +++++++++++++++++++++++++++++++++++++++++
#    FT20-Server STATS
#
# COUNTERS:
# Inbound: {FT20_FinPacket=1, FT20_DataPacket=65, bytes=66593, FT20_UploadPacket=1}
# Outbound: {bytes=2178, FT20_AckPacket=66}
# ------------------------------------
# RTT/Timeout Stats:
# RTT (max/avg/min/#samples) : ?, ?, ?, ?
# Timeout (max/avg/min/#samples) : ?, ?, ?, ?
# timeout events: 0
# ------------------------------------
# Transfer Rates:
# Inbound mean transfer rate: 182.57 Kbit/s
# Outbound mean transfer rate: 5.97 Kbit/s
# +++++++++++++++++++++++++++++++++++++++++
#
# log:    FT20-Server time 2918 node 1 SENDING: ACK<66, 66, 2898>
# log: FT20-ClientSW time 2938 node 0 GOT: ACK<66, 66, 2898>
# log: FT20-ClientSW time 2938 node 0 All Done. Transfer complete...
#
# +++++++++++++++++++++++++++++++++++++++++
# FT20-ClientSW STATS
#
# COUNTERS:
# Inbound: {bytes=2211, FT20_AckPacket=67}
# Outbound: {FT20_FinPacket=1, FT20_DataPacket=65, bytes=66593, FT20_UploadPacket=1}
# ------------------------------------
# RTT/Timeout Stats:
# RTT (max/avg/min/#samples) : ?, ?, ?, ?
# Timeout (max/avg/min/#samples) : ?, ?, ?, ?
# timeout events: 0
# ------------------------------------
# Transfer Rates:
# Inbound mean transfer rate: 6.02 Kbit/s
# Outbound mean transfer rate: 181.33 Kbit/s
# +++++++++++++++++++++++++++++++++++++++++
#
#
# simulation ended - last processing step with clock = 3898

# %% [markdown]
# ---
#
# # Assignment-2 Deliverables
#
# *IMPORTANT: study chapter 6 of the book supporting the course to fully understand these protocols.*
#
# ## First Deliverable - GoBackN
#
# Implement the sliding window version of the FT20Protocol, using the **GoBackN** technique.
#
# Your *client* should be implemented in a class named `FT20ClientGBN`. It has to accept 3 arguments, in this order:
#
# `filename` - the file being transferred;
#
# `blocksize` - the size of file blocks sent in each `DATA` packet;
#
# `windowsize` - the capacity of the window in number of blocks.
#
# For tests use the provided server FT20Server. Your client should work correctly with the provided server. You must ***not change*** the server in any way.
#
# Use a fixed, default timeout value of 1000 ms.
#
# Watch out for corner cases, such as: files that fit in a single block, files with length that is whole multiple of the blocksize.
#
# Test your implementation against configurations [config-2.1](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/configs/config-2.1.txt) [config-2.2](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/configs/config-2.2.txt) [config-2.3](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/configs/config-2.3.txt)
#
# Your solution should be as general as possible. It will be tested against a variety of configurations in addition to those provided.
#
# Confirm the transfered file is identical to the original. You can use the `diff` command for that.
#
# ***Important Notes***
# * Look at the implementation constraints at the end of this notebook. Violating them will penalize your final evaluation.
# * If you only implement this deliverable, your work evaluation will be at most 15 marks.
#
#
# ## Optative Deliverable - Selective Repeat.
#
# Improve your previous delivery by using the techniques introduced by the **Selective Repeat** version of the protocol.
#
# Your *client* should be implemented in a class named `FT20ClientSR`.
#
# Use a fixed default timeout value of 1000 ms.
#
# Leverage the `sSeqN` field present in `ACK` packets to selectively retransmit expired packets.
#
# Using the provided configuration files, compare the results of this version against those for the GBN version of the first deliverable.
#
# ***Important Notes***
# * Look at the implementation constraints at the end of this notebook. Violating them will penalize your final evaluation.
# * If you implement this optative deliverable, your work evaluation can be increased by up to 3 marks.
#
# ## Optative Deliverable - Adaptative timeout
#
# You can leverage the `timestamp` field present in most packets to estimate RTT and improve the performance of your best solution (the GBN one if you have not implemented the SR one, or the SR one if you have implemented it) using an adaptative timeout.
#
# Your *client* should be implemented in a class named `FT20ClientGBN_DT` or `FT20ClientGBN_DT` depending on your best solution.
#
# The fixed timeout value used in the previous solutions should be replaced by a dynamic value based on an estimate of the network RTT between client and server.
#
# *IMPORTANT: please study section 7.2 of the book supporting the course for more information on TCP dynamic
# timeouts which you may use as inspiration*
#
# Compare the results of this version against those for the fixed timeout versions of the previous deliverables, using the provided configuration files.
#
# ***Important Note***
# * If you implement this optative improvement, your work evaluation can be be increased by up to 2 marks.
#
#
# ## Statistics
#
# A statistics report should be presented at the end of each file transfer.
#
# Refer to the provided reference Stop&Wait version [FT20ClientSW](https://github.com/jlegatheaux/RC2020-assignments/blob/master/assignment-2/src/FT20ClientSW.java) to see how to produce the statistics report.
#
# ## Implementation Constraints
#
# You **must not change** the provided **FT20_* classes** in any way. Note that for evaluation purposes, your code will be tested against the **original** versions of the files.
#
# You are only allowed to send 1 packet, on each 1 ms `on_clock_tick` round. Retransmitting *expired packets* takes priority compared to sending fresh packets added to the sliding window. In other words, *older packets* take
# priority.
#
# You cannot send `DATA` packets in the `on_timeout` upcall. `UPLOAD` and `FIN` packets are allowed.
